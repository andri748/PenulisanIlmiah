# %% [markdown]
# # ANALISA PERBEDAAN ANALISIS SENTIMEN SECARA MANUAL DENGAN MENGGUNAKAN LIBRARY TEXTBLOB TERHADAP KATA VAKSIN DENGAN DATA TWEETS BAHASA INGGRIS

# %% [markdown]
# ### Pengambilan data

# %%
import pandas as pd
# !pip install snscrape 
import snscrape.modules.twitter as sntwitter
import itertools
 df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
   'vaccine').get_items(), 100))[[ 'date', 'content']]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset_vaccine11aprdatecontent.csv')

# %%
df.head(10)
# Out:
#                         date  \
# 0  2022-04-11 15:29:55+00:00
# 1  2022-04-11 15:29:55+00:00
# 2  2022-04-11 15:29:54+00:00
# 3  2022-04-11 15:29:53+00:00
# 4  2022-04-11 15:29:53+00:00
# 5  2022-04-11 15:29:53+00:00
# 6  2022-04-11 15:29:53+00:00
# 7  2022-04-11 15:29:52+00:00
# 8  2022-04-11 15:29:51+00:00
# 9  2022-04-11 15:29:51+00:00
#
#                                              content
# 0  2/  Production has slowed, further research ha...
# 1  SVP, je suis un vieux boomer mais je ne regard...
# 2  Canadian Dr. Given Psychiatric Detention for H...
# 3  @IppokratisAnge1 Vaccines reduce your likeliho...
# 4  @koenig_lydie @jeangarr78 l'OTAN est géré par ...
# 5  @SuSpenceG @Lard_Baron @JDrewsyBC The previous...
# 6  @k_b_lvi Again, so show the data used to deter...
# 7                               @Nkosi_Shebi 3452839
# 8  @oakaged22 @aflink27 @RyanAFournier Oh, so she...
# 9  I seriously think they should be checking into...

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/dataset_vaccine11aprdatecontent.csv', index=None)

# %%
df = df.drop(columns=['date'])

# %%
df
# Out:
#                                               content
# 0   2/  Production has slowed, further research ha...
# 1   SVP, je suis un vieux boomer mais je ne regard...
# 2   Canadian Dr. Given Psychiatric Detention for H...
# 3   @IppokratisAnge1 Vaccines reduce your likeliho...
# 4   @koenig_lydie @jeangarr78 l'OTAN est géré par ...
# ..                                                ...
# 95  @andrew7rd @globalism_no @Hansy_Democrat @wake...
# 96         @Tuliodna No vaccines for under 5 still. 😫
# 97  @apsmunro Comprehensive investigations reveale...
# 98  @Sites4Congress @loveis716 You’re right. He’s ...
# 99  @Gimpuslegend @scrufwiththecat @wohyeah_wohyea...
#
# [100 rows x 1 columns]

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/dataset_vaccine11aprcontent.csv', index=None)

# %% [markdown]
# ### Pembersihan data

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset_vaccine11aprcontent.csv')

# %%
df
# Out:
#                                               content
# 0   2/  Production has slowed, further research ha...
# 1   SVP, je suis un vieux boomer mais je ne regard...
# 2   Canadian Dr. Given Psychiatric Detention for H...
# 3   @IppokratisAnge1 Vaccines reduce your likeliho...
# 4   @koenig_lydie @jeangarr78 l'OTAN est géré par ...
# ..                                                ...
# 95  @andrew7rd @globalism_no @Hansy_Democrat @wake...
# 96         @Tuliodna No vaccines for under 5 still. 😫
# 97  @apsmunro Comprehensive investigations reveale...
# 98  @Sites4Congress @loveis716 You’re right. He’s ...
# 99  @Gimpuslegend @scrufwiththecat @wohyeah_wohyea...
#
# [100 rows x 1 columns]

# %% [markdown]
# clean 1 pembersihan spesial karakter, tag @ dan angka

# %%
import re 
import string 

def clean_text(tweet):
    tweet = tweet.lower() 
    tweet = re.sub('@[^\s]+', '', tweet) 
    tweet = re.sub('\[.*?\]', '', tweet) 
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', '', tweet) 
    tweet = re.sub('[%s]' % re.escape(string.punctuation), '', tweet) 
    tweet = re.sub('\w*\d\w*', '', tweet) 
    tweet = re.sub('[‘’“”…]', '', tweet) 
    tweet = re.sub('\n', '', tweet) 
    return tweet

    
tweet = lambda x: clean_text(x)

# %%
df['clean1'] = pd.DataFrame(df.content.apply(tweet))
df
# Out:
#                                               content  \
# 0   2/  Production has slowed, further research ha...
# 1   SVP, je suis un vieux boomer mais je ne regard...
# 2   Canadian Dr. Given Psychiatric Detention for H...
# 3   @IppokratisAnge1 Vaccines reduce your likeliho...
# 4   @koenig_lydie @jeangarr78 l'OTAN est géré par ...
# ..                                                ...
# 95  @andrew7rd @globalism_no @Hansy_Democrat @wake...
# 96         @Tuliodna No vaccines for under 5 still. 😫
# 97  @apsmunro Comprehensive investigations reveale...
# 98  @Sites4Congress @loveis716 You’re right. He’s ...
# 99  @Gimpuslegend @scrufwiththecat @wohyeah_wohyea...
#
#                                                clean1
# 0     production has slowed further research has s...
# 1   svp je suis un vieux boomer mais je ne regarde...
# 2   canadian dr given psychiatric detention for hi...
# 3    vaccines reduce your likelihood of needing ho...
# 4     lotan est géré par les etats unison peut mie...
# ..                                                ...
# 95          youre right its not  and i didnt say i...
# 96                     no vaccines for under  still 😫
# 97   comprehensive investigations revealed consist...
# 98    youre right hes caved to the maga base more ...
# 99      there is no longterm study into the effect...
#
# [100 rows x 2 columns]

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/dataset_vaccine11aprclean1.csv', index=None)

# %% [markdown]
# clean 2 stopwords penghapusan kata seperti are, the, girl

# %%
import nltk 
nltk.download('stopwords') 
from nltk.corpus import stopwords 
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
additional  = ['rt','rts','retweet'] 
swords = set().union(stopwords.words('english'), additional) 

df['clean2'] = (df['clean1'].apply(lambda x: ' '.join([word for word in x.split() if word not in (swords)]))) 
df
# Out:
#                                               content  \
# 0   2/  Production has slowed, further research ha...
# 1   SVP, je suis un vieux boomer mais je ne regard...
# 2   Canadian Dr. Given Psychiatric Detention for H...
# 3   @IppokratisAnge1 Vaccines reduce your likeliho...
# 4   @koenig_lydie @jeangarr78 l'OTAN est géré par ...
# ..                                                ...
# 95  @andrew7rd @globalism_no @Hansy_Democrat @wake...
# 96         @Tuliodna No vaccines for under 5 still. 😫
# 97  @apsmunro Comprehensive investigations reveale...
# 98  @Sites4Congress @loveis716 You’re right. He’s ...
# 99  @Gimpuslegend @scrufwiththecat @wohyeah_wohyea...
#
#                                                clean1  \
# 0     production has slowed further research has s...
# 1   svp je suis un vieux boomer mais je ne regarde...
# 2   canadian dr given psychiatric detention for hi...
# 3    vaccines reduce your likelihood of needing ho...
# 4     lotan est géré par les etats unison peut mie...
# ..                                                ...
# 95          youre right its not  and i didnt say i...
# 96                     no vaccines for under  still 😫
# 97   comprehensive investigations revealed consist...
# 98    youre right hes caved to the maga base more ...
# 99      there is no longterm study into the effect...
#
#                                                clean2
# 0   production slowed research stalled visit world...
# 1   svp je suis un vieux boomer mais je ne regarde...
# 2   canadian dr given psychiatric detention highli...
# 3   vaccines reduce likelihood needing hospitaliza...
# 4   lotan est géré par les etats unison peut mieux...
# ..                                                ...
# 95  youre right didnt say contracted something vac...
# 96                                   vaccines still 😫
# 97  comprehensive investigations revealed consiste...
# 98  youre right hes caved maga base covid policy a...
# 99  longterm study effects puberty blockers true i...
#
# [100 rows x 3 columns]

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/dataset_vaccine11aprclean2.csv', index=None)

# %% [markdown]
# clean 3 stemming

# %%
from nltk.stem.porter import PorterStemmer

# %%
#Stemming the text
def simple_stemmer(text):
    ps=nltk.porter.PorterStemmer()
    text= ' '.join([ps.stem(word) for word in text.split()])
    return text
#Apply function on review column
df['clean3']=df['clean2'].apply(simple_stemmer)

# %%
df
# Out:
#                                               content  \
# 0   2/  Production has slowed, further research ha...
# 1   SVP, je suis un vieux boomer mais je ne regard...
# 2   Canadian Dr. Given Psychiatric Detention for H...
# 3   @IppokratisAnge1 Vaccines reduce your likeliho...
# 4   @koenig_lydie @jeangarr78 l'OTAN est géré par ...
# ..                                                ...
# 95  @andrew7rd @globalism_no @Hansy_Democrat @wake...
# 96         @Tuliodna No vaccines for under 5 still. 😫
# 97  @apsmunro Comprehensive investigations reveale...
# 98  @Sites4Congress @loveis716 You’re right. He’s ...
# 99  @Gimpuslegend @scrufwiththecat @wohyeah_wohyea...
#
#                                                clean1  \
# 0     production has slowed further research has s...
# 1   svp je suis un vieux boomer mais je ne regarde...
# 2   canadian dr given psychiatric detention for hi...
# 3    vaccines reduce your likelihood of needing ho...
# 4     lotan est géré par les etats unison peut mie...
# ..                                                ...
# 95          youre right its not  and i didnt say i...
# 96                     no vaccines for under  still 😫
# 97   comprehensive investigations revealed consist...
# 98    youre right hes caved to the maga base more ...
# 99      there is no longterm study into the effect...
#
#                                                clean2  \
# 0   production slowed research stalled visit world...
# 1   svp je suis un vieux boomer mais je ne regarde...
# 2   canadian dr given psychiatric detention highli...
# 3   vaccines reduce likelihood needing hospitaliza...
# 4   lotan est géré par les etats unison peut mieux...
# ..                                                ...
# 95  youre right didnt say contracted something vac...
# 96                                   vaccines still 😫
# 97  comprehensive investigations revealed consiste...
# 98  youre right hes caved maga base covid policy a...
# 99  longterm study effects puberty blockers true i...
#
#                                                clean3
# 0   product slow research stall visit world health...
# 1   svp je sui un vieux boomer mai je ne regard pa...
# 2   canadian dr given psychiatr detent highlight v...
# 3   vaccin reduc likelihood need hospit ventil get...
# 4   lotan est géré par le etat unison peut mieux f...
# ..                                                ...
# 95  your right didnt say contract someth vaccin me...
# 96                                     vaccin still 😫
# 97  comprehens investig reveal consist pathophysio...
# 98  your right he cave maga base covid polici actu...
# 99  longterm studi effect puberti blocker true iso...
#
# [100 rows x 4 columns]

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/dataset_vaccine11aprclean3.csv', index=None)

# %% [markdown]
# membuat tokenize kolom tokens dari kolom clean3

# %%
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
df['tokens'] = pd.DataFrame(df['clean3'].apply(nltk.word_tokenize))
df
# Out:
#                                               content  \
# 0   2/  Production has slowed, further research ha...
# 1   SVP, je suis un vieux boomer mais je ne regard...
# 2   Canadian Dr. Given Psychiatric Detention for H...
# 3   @IppokratisAnge1 Vaccines reduce your likeliho...
# 4   @koenig_lydie @jeangarr78 l'OTAN est géré par ...
# ..                                                ...
# 95  @andrew7rd @globalism_no @Hansy_Democrat @wake...
# 96         @Tuliodna No vaccines for under 5 still. 😫
# 97  @apsmunro Comprehensive investigations reveale...
# 98  @Sites4Congress @loveis716 You’re right. He’s ...
# 99  @Gimpuslegend @scrufwiththecat @wohyeah_wohyea...
#
#                                                clean1  \
# 0     production has slowed further research has s...
# 1   svp je suis un vieux boomer mais je ne regarde...
# 2   canadian dr given psychiatric detention for hi...
# 3    vaccines reduce your likelihood of needing ho...
# 4     lotan est géré par les etats unison peut mie...
# ..                                                ...
# 95          youre right its not  and i didnt say i...
# 96                     no vaccines for under  still 😫
# 97   comprehensive investigations revealed consist...
# 98    youre right hes caved to the maga base more ...
# 99      there is no longterm study into the effect...
#
#                                                clean2  \
# 0   production slowed research stalled visit world...
# 1   svp je suis un vieux boomer mais je ne regarde...
# 2   canadian dr given psychiatric detention highli...
# 3   vaccines reduce likelihood needing hospitaliza...
# 4   lotan est géré par les etats unison peut mieux...
# ..                                                ...
# 95  youre right didnt say contracted something vac...
# 96                                   vaccines still 😫
# 97  comprehensive investigations revealed consiste...
# 98  youre right hes caved maga base covid policy a...
# 99  longterm study effects puberty blockers true i...
#
#                                                clean3  \
# 0   product slow research stall visit world health...
# 1   svp je sui un vieux boomer mai je ne regard pa...
# 2   canadian dr given psychiatr detent highlight v...
# 3   vaccin reduc likelihood need hospit ventil get...
# 4   lotan est géré par le etat unison peut mieux f...
# ..                                                ...
# 95  your right didnt say contract someth vaccin me...
# 96                                     vaccin still 😫
# 97  comprehens investig reveal consist pathophysio...
# 98  your right he cave maga base covid polici actu...
# 99  longterm studi effect puberti blocker true iso...
#
#                                                tokens
# 0   [product, slow, research, stall, visit, world,...
# 1   [svp, je, sui, un, vieux, boomer, mai, je, ne,...
# 2   [canadian, dr, given, psychiatr, detent, highl...
# 3   [vaccin, reduc, likelihood, need, hospit, vent...
# 4   [lotan, est, géré, par, le, etat, unison, peut...
# ..                                                ...
# 95  [your, right, didnt, say, contract, someth, va...
# 96                                 [vaccin, still, 😫]
# 97  [comprehens, investig, reveal, consist, pathop...
# 98  [your, right, he, cave, maga, base, covid, pol...
# 99  [longterm, studi, effect, puberti, blocker, tr...
#
# [100 rows x 5 columns]

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/dataset_vaccine11aprtokens.csv', index=None)

# %% [markdown]
# ### Melabel sentimen secara manual

# %%
# berikan label secara manual terlebih dahulu
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset_vaccine11aprsentimanual.csv')

# %%
df
# Out:
#                                               content  \
# 0   2/  Production has slowed, further research ha...
# 1   SVP, je suis un vieux boomer mais je ne regard...
# 2   Canadian Dr. Given Psychiatric Detention for H...
# 3   @IppokratisAnge1 Vaccines reduce your likeliho...
# 4   @koenig_lydie @jeangarr78 l'OTAN est géré par ...
# ..                                                ...
# 95  @andrew7rd @globalism_no @Hansy_Democrat @wake...
# 96         @Tuliodna No vaccines for under 5 still. 😫
# 97  @apsmunro Comprehensive investigations reveale...
# 98  @Sites4Congress @loveis716 You’re right. He’s ...
# 99  @Gimpuslegend @scrufwiththecat @wohyeah_wohyea...
#
#                                                clean1  \
# 0     production has slowed further research has s...
# 1   svp je suis un vieux boomer mais je ne regarde...
# 2   canadian dr given psychiatric detention for hi...
# 3    vaccines reduce your likelihood of needing ho...
# 4     lotan est géré par les etats unison peut mie...
# ..                                                ...
# 95          youre right its not  and i didnt say i...
# 96                     no vaccines for under  still 😫
# 97   comprehensive investigations revealed consist...
# 98    youre right hes caved to the maga base more ...
# 99      there is no longterm study into the effect...
#
#                                                clean2  \
# 0   production slowed research stalled visit world...
# 1   svp je suis un vieux boomer mais je ne regarde...
# 2   canadian dr given psychiatric detention highli...
# 3   vaccines reduce likelihood needing hospitaliza...
# 4   lotan est géré par les etats unison peut mieux...
# ..                                                ...
# 95  youre right didnt say contracted something vac...
# 96                                   vaccines still 😫
# 97  comprehensive investigations revealed consiste...
# 98  youre right hes caved maga base covid policy a...
# 99  longterm study effects puberty blockers true i...
#
#                                                clean3  \
# 0   product slow research stall visit world health...
# 1   svp je sui un vieux boomer mai je ne regard pa...
# 2   canadian dr given psychiatr detent highlight v...
# 3   vaccin reduc likelihood need hospit ventil get...
# 4   lotan est géré par le etat unison peut mieux f...
# ..                                                ...
# 95  your right didnt say contract someth vaccin me...
# 96                                     vaccin still 😫
# 97  comprehens investig reveal consist pathophysio...
# 98  your right he cave maga base covid polici actu...
# 99  longterm studi effect puberti blocker true iso...
#
#                                                tokens sentimen_manual
# 0   ['product', 'slow', 'research', 'stall', 'visi...          netral
# 1   ['svp', 'je', 'sui', 'un', 'vieux', 'boomer', ...          netral
# 2   ['canadian', 'dr', 'given', 'psychiatr', 'dete...          netral
# 3   ['vaccin', 'reduc', 'likelihood', 'need', 'hos...          netral
# 4   ['lotan', 'est', 'géré', 'par', 'le', 'etat', ...          netral
# ..                                                ...             ...
# 95  ['your', 'right', 'didnt', 'say', 'contract', ...         negatif
# 96                           ['vaccin', 'still', '😫']         negatif
# 97  ['comprehens', 'investig', 'reveal', 'consist'...         negatif
# 98  ['your', 'right', 'he', 'cave', 'maga', 'base'...         negatif
# 99  ['longterm', 'studi', 'effect', 'puberti', 'bl...         negatif
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Melabel otomatis menggunakan library Textblob

# %%
from textblob import TextBlob

# %%
df['tokens'] = df['tokens'].astype('str')
def get_polarity(text):
  return TextBlob(text).sentiment.polarity

# %%
df['polarity'] = df['tokens'].apply(get_polarity)

# %%
df
# Out:
#                                               content  \
# 0   2/  Production has slowed, further research ha...
# 1   SVP, je suis un vieux boomer mais je ne regard...
# 2   Canadian Dr. Given Psychiatric Detention for H...
# 3   @IppokratisAnge1 Vaccines reduce your likeliho...
# 4   @koenig_lydie @jeangarr78 l'OTAN est géré par ...
# ..                                                ...
# 95  @andrew7rd @globalism_no @Hansy_Democrat @wake...
# 96         @Tuliodna No vaccines for under 5 still. 😫
# 97  @apsmunro Comprehensive investigations reveale...
# 98  @Sites4Congress @loveis716 You’re right. He’s ...
# 99  @Gimpuslegend @scrufwiththecat @wohyeah_wohyea...
#
#                                                clean1  \
# 0     production has slowed further research has s...
# 1   svp je suis un vieux boomer mais je ne regarde...
# 2   canadian dr given psychiatric detention for hi...
# 3    vaccines reduce your likelihood of needing ho...
# 4     lotan est géré par les etats unison peut mie...
# ..                                                ...
# 95          youre right its not  and i didnt say i...
# 96                     no vaccines for under  still 😫
# 97   comprehensive investigations revealed consist...
# 98    youre right hes caved to the maga base more ...
# 99      there is no longterm study into the effect...
#
#                                                clean2  \
# 0   production slowed research stalled visit world...
# 1   svp je suis un vieux boomer mais je ne regarde...
# 2   canadian dr given psychiatric detention highli...
# 3   vaccines reduce likelihood needing hospitaliza...
# 4   lotan est géré par les etats unison peut mieux...
# ..                                                ...
# 95  youre right didnt say contracted something vac...
# 96                                   vaccines still 😫
# 97  comprehensive investigations revealed consiste...
# 98  youre right hes caved maga base covid policy a...
# 99  longterm study effects puberty blockers true i...
#
#                                                clean3  \
# 0   product slow research stall visit world health...
# 1   svp je sui un vieux boomer mai je ne regard pa...
# 2   canadian dr given psychiatr detent highlight v...
# 3   vaccin reduc likelihood need hospit ventil get...
# 4   lotan est géré par le etat unison peut mieux f...
# ..                                                ...
# 95  your right didnt say contract someth vaccin me...
# 96                                     vaccin still 😫
# 97  comprehens investig reveal consist pathophysio...
# 98  your right he cave maga base covid polici actu...
# 99  longterm studi effect puberti blocker true iso...
#
#                                                tokens sentimen_manual  \
# 0   ['product', 'slow', 'research', 'stall', 'visi...          netral
# 1   ['svp', 'je', 'sui', 'un', 'vieux', 'boomer', ...          netral
# 2   ['canadian', 'dr', 'given', 'psychiatr', 'dete...          netral
# 3   ['vaccin', 'reduc', 'likelihood', 'need', 'hos...          netral
# 4   ['lotan', 'est', 'géré', 'par', 'le', 'etat', ...          netral
# ..                                                ...             ...
# 95  ['your', 'right', 'didnt', 'say', 'contract', ...         negatif
# 96                           ['vaccin', 'still', '😫']         negatif
# 97  ['comprehens', 'investig', 'reveal', 'consist'...         negatif
# 98  ['your', 'right', 'he', 'cave', 'maga', 'base'...         negatif
# 99  ['longterm', 'studi', 'effect', 'puberti', 'bl...         negatif
#
#     polarity
# 0  -0.150000
# 1   0.000000
# 2   0.000000
# 3  -0.714286
# 4   0.700000
# ..       ...
# 95 -0.098214
# 96  0.000000
# 97  0.000000
# 98  0.027143
# 99  0.250000
#
# [100 rows x 7 columns]

# %%
df['sentimen_textblob']=''
df.loc[df.polarity>0,'sentimen_textblob']='positif'
df.loc[df.polarity==0,'sentimen_textblob']='netral'
df.loc[df.polarity<0,'sentimen_textblob']='negatif'

# %%
df
# Out:
#                                               content  \
# 0   2/  Production has slowed, further research ha...
# 1   SVP, je suis un vieux boomer mais je ne regard...
# 2   Canadian Dr. Given Psychiatric Detention for H...
# 3   @IppokratisAnge1 Vaccines reduce your likeliho...
# 4   @koenig_lydie @jeangarr78 l'OTAN est géré par ...
# ..                                                ...
# 95  @andrew7rd @globalism_no @Hansy_Democrat @wake...
# 96         @Tuliodna No vaccines for under 5 still. 😫
# 97  @apsmunro Comprehensive investigations reveale...
# 98  @Sites4Congress @loveis716 You’re right. He’s ...
# 99  @Gimpuslegend @scrufwiththecat @wohyeah_wohyea...
#
#                                                clean1  \
# 0     production has slowed further research has s...
# 1   svp je suis un vieux boomer mais je ne regarde...
# 2   canadian dr given psychiatric detention for hi...
# 3    vaccines reduce your likelihood of needing ho...
# 4     lotan est géré par les etats unison peut mie...
# ..                                                ...
# 95          youre right its not  and i didnt say i...
# 96                     no vaccines for under  still 😫
# 97   comprehensive investigations revealed consist...
# 98    youre right hes caved to the maga base more ...
# 99      there is no longterm study into the effect...
#
#                                                clean2  \
# 0   production slowed research stalled visit world...
# 1   svp je suis un vieux boomer mais je ne regarde...
# 2   canadian dr given psychiatric detention highli...
# 3   vaccines reduce likelihood needing hospitaliza...
# 4   lotan est géré par les etats unison peut mieux...
# ..                                                ...
# 95  youre right didnt say contracted something vac...
# 96                                   vaccines still 😫
# 97  comprehensive investigations revealed consiste...
# 98  youre right hes caved maga base covid policy a...
# 99  longterm study effects puberty blockers true i...
#
#                                                clean3  \
# 0   product slow research stall visit world health...
# 1   svp je sui un vieux boomer mai je ne regard pa...
# 2   canadian dr given psychiatr detent highlight v...
# 3   vaccin reduc likelihood need hospit ventil get...
# 4   lotan est géré par le etat unison peut mieux f...
# ..                                                ...
# 95  your right didnt say contract someth vaccin me...
# 96                                     vaccin still 😫
# 97  comprehens investig reveal consist pathophysio...
# 98  your right he cave maga base covid polici actu...
# 99  longterm studi effect puberti blocker true iso...
#
#                                                tokens sentimen_manual  \
# 0   ['product', 'slow', 'research', 'stall', 'visi...          netral
# 1   ['svp', 'je', 'sui', 'un', 'vieux', 'boomer', ...          netral
# 2   ['canadian', 'dr', 'given', 'psychiatr', 'dete...          netral
# 3   ['vaccin', 'reduc', 'likelihood', 'need', 'hos...          netral
# 4   ['lotan', 'est', 'géré', 'par', 'le', 'etat', ...          netral
# ..                                                ...             ...
# 95  ['your', 'right', 'didnt', 'say', 'contract', ...         negatif
# 96                           ['vaccin', 'still', '😫']         negatif
# 97  ['comprehens', 'investig', 'reveal', 'consist'...         negatif
# 98  ['your', 'right', 'he', 'cave', 'maga', 'base'...         negatif
# 99  ['longterm', 'studi', 'effect', 'puberti', 'bl...         negatif
#
#     polarity sentimen_textblob
# 0  -0.150000           negatif
# 1   0.000000            netral
# 2   0.000000            netral
# 3  -0.714286           negatif
# 4   0.700000           positif
# ..       ...               ...
# 95 -0.098214           negatif
# 96  0.000000            netral
# 97  0.000000            netral
# 98  0.027143           positif
# 99  0.250000           positif
#
# [100 rows x 8 columns]

# %% [markdown]
# # Menghitung Jumlah Sentimen

# %% [markdown]
# ### Sentimen Manual

# %%
df['sentimen_manual'].value_counts()
# Out:
# negatif    37
# netral     36
# positif    27
# Name: sentimen_manual, dtype: int64

# %% [markdown]
# ### Sentimen TextBlob

# %%
df['sentimen_textblob'].value_counts()
# Out:
# netral     46
# positif    37
# negatif    17
# Name: sentimen_textblob, dtype: int64

# %% [markdown]
# #Visualization

# %% [markdown]
# # Bar Chart

# %% [markdown]
# ### Sentimen TextBlob

# %%
df.sentimen_textblob.value_counts().plot(kind='bar',title="Sentimen Textblob")

# %% [markdown]
# ### Sentimen Manual

# %%
df.sentimen_manual.value_counts().plot(kind='bar',title="Sentimen manual")

# %% [markdown]
# # Pie Chart

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Sentimen manual

# %%
#define data
data = [37, 36, 27]
labels = ['negatif', 'netral', 'positif']

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:3]

#create pie chart
plt.pie(data, labels = labels, colors = colors, autopct='%.0f')
plt.show()

# %% [markdown]
# ### Sentimen TextBlob

# %%
#define data
data = [46, 37, 17]
labels = ['netral', 'positif', 'negatif']

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:3]

#create pie chart
plt.pie(data, labels = labels, colors = colors, autopct='%.0f')
plt.show()
